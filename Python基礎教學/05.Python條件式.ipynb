# %% [markdown]
# # Python 基礎教學-條件式
#
# ## 中正大學資管系 (20181014)

# %% [markdown]
# # Python 的 if statement

# %% [markdown]
# ## Syntax (語法)
#
# ```python
# if (statement)：
#     欲執行的程式
#
# ```

# %%
a = 10
b = 20

if a > b:
    print("a > b")

# %%
a = 10
b = 20 

if (a > b):
    print("a > b")

# %%
a = 10
b = 20

if a > b:
    print("a > b")
elif a < b:
    print("a < b")
else:
    print("a = b")
# Out:
# a < b

# %%
a = 10
b = 20

if a != b:
    print("a != b")
else:
    print("a = b")
# Out:
# a != b

# %%
lists = [1, 2, 3]

if lists:
    for l in lists:
        print(l)
# Out:
# 1
# 2
# 3

# %%
s = ""

if s:
    print("s 的值是：", s)
else:
    print("s 是空字串")
# Out:
# s 是空字串

# %% [markdown]
# ## 多條件

# %%
a = 10

if 0 <= a <= 20:
    print("a 符合條件")
else:
    print("a 不符合條件")
# Out:
# a 符合條件

# %%
if 20 >= a >= 0:
    print("a 符合條件")
else:
    print("a 不符合條件")
# Out:
# a 符合條件

# %%
s = ""

if not s:
    print("s 是空字串")
# Out:
# s 是空字串
